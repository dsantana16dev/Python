# %%
import pandas as pd

# %%
rel2015 = pd.read_csv('2015.csv')
rel2016 = pd.read_csv('2016.csv')

# %%
rel2015.head(3)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204

# %%
rel2016.head(3)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# 2                   1.42666  1.18326                   0.86733  0.56624
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.44453     0.36171            2.73939
# ...

# %% [markdown]
# Celulas diferentes:
# 2015 Standard Erro <=> 2016 Lower Confidence Interval / Upper Confidence Interval

# %%
rel2015.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
rel2015.shape
# Out:
# (158, 12)

# %%
rel2016.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
rel2016.shape
# Out:
# (157, 13)

# %% [markdown]
# Juntar as duas tabelas

# %%
df = pd.concat([rel2015, rel2016], ignore_index=True, join='inner')

# %%
df.head(30)
# Out:
#                  Country                           Region  Happiness Rank  \
# 0            Switzerland                   Western Europe               1
# 1                Iceland                   Western Europe               2
# 2                Denmark                   Western Europe               3
# 3                 Norway                   Western Europe               4
# 4                 Canada                    North America               5
# 5                Finland                   Western Europe               6
# 6            Netherlands                   Western Europe               7
# 7                 Sweden                   Western Europe               8
# 8            New Zealand        Australia and New Zealand               9
# 9              Australia        Australia and New Zealand              10
# 10                Israel  Middle East and Northern Africa              11
# 11            Costa Rica      Latin America and Caribbean              12
# ...

# %%
df.shape
# Out:
# (315, 11)

# %% [markdown]
# Encontrar os numeros Nulos: não encontrei

# %%
def show_nulls2016(rel2016):
    total_nan2016 = rel2016.isnull().sum()
    perc_nan2016 = total_nan2016/len(rel2016)*100
    return total_nan2016, perc_nan2016

# %%
print('total_nulos 2016', show_nulls2016(rel2016=rel2016)[0])
# Out:
# total_nulos 2016 Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Lower Confidence Interval        0
# Upper Confidence Interval        0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
def show_nulls2015(rel2015):
    total_nan2015 = rel2015.isnull().sum()
    perc_nan2015 = total_nan2015/len(rel2015)*100
    return total_nan2015, perc_nan2015

# %%
print('Total nulos 2015', show_nulls2015(rel2015=rel2015)[0])
# Out:
# Total nulos 2015 Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
def show_nulls(df):
    total_nan = df.isnull().sum()
    perc_nan = total_nan/len(df)*100
    return total_nan, perc_nan

# %%
print('total_nulos', show_nulls(df=df)[0])
# Out:
# total_nulos Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
health = df['Health (Life Expectancy)']
print(health)
# Out:
# 0      0.94143
# 1      0.94784
# 2      0.87464
# 3      0.88521
# 4      0.90563
#         ...
# 310    0.21028
# 311    0.17344
# 312    0.24811
# 313    0.62994
# 314    0.15747
# Name: Health (Life Expectancy), Length: 315, dtype: float64

# %%
family = df['Family']
print(family)
# Out:
# 0      1.34951
# 1      1.40223
# 2      1.36058
# 3      1.33095
# 4      1.32261
#         ...
# 310    0.10419
# 311    0.11037
# 312    0.00000
# 313    0.14866
# 314    0.23442
# Name: Family, Length: 315, dtype: float64

# %%
plt.scatter(family, health)

# %%
happiness = df['Happiness Score']
trust = df['Trust (Government Corruption)']
plt.plot(happiness, trust)
plt.show()

# %%
df.loc[df['Country']=='Canada']
# Out:
#     Country         Region  Happiness Rank  Happiness Score  \
# 4    Canada  North America               5            7.427
# 163  Canada  North America               6            7.404
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 4                     1.32629  1.32261                   0.90563  0.63297
# 163                   1.44015  1.09610                   0.82760  0.57370
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 4                          0.32957     0.45811            2.45176
# 163                        0.31329     0.44834            2.70485
