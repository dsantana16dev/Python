# %%
import pandas as pd
df = pd.read_table('iris.data', sep=',', header = None)
df.columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'type']

df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width         type
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
from plotnine import*
(
    ggplot(df) +
    geom_histogram(aes(x='petal_width'))
)
# Out:
# C:\Users\Daninique\anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:95: PlotnineWarning: 'stat_bin()' using 'bins = 5'. Pick better value with 'binwidth'.
# <ggplot: (185324128368)>

# %%
(
    ggplot(df) +
    
    geom_point(aes(x='petal_width', y ='sepal_width'))
)
# Out:
# <ggplot: (185325807153)>

# %%
(

    ggplot(df) +

     geom_histogram(aes(x='petal_width'), color = 'blue')

)
# Out:
# C:\Users\Daninique\anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:95: PlotnineWarning: 'stat_bin()' using 'bins = 5'. Pick better value with 'binwidth'.
# <ggplot: (185324655909)>

# %%
(

    ggplot(df) +

     geom_point(aes(x='petal_width', y = 'sepal_width'), color = 'red')

)
# Out:
# <ggplot: (185327217625)>

# %%
(

    ggplot(df) +

     geom_histogram(aes(x='petal_width'), color = 'blue', fill = 'lightgreen')

)
# Out:
# C:\Users\Daninique\anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:95: PlotnineWarning: 'stat_bin()' using 'bins = 5'. Pick better value with 'binwidth'.
# <ggplot: (185325754712)>

# %%
(

    ggplot(df) +

     geom_histogram(aes(x='petal_width'),

                    color = 'blue',

                    fill = 'lightgreen',

                    alpha = 0.2,

                    linetype='solid')

)
# Out:
# C:\Users\Daninique\anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:95: PlotnineWarning: 'stat_bin()' using 'bins = 5'. Pick better value with 'binwidth'.
# <ggplot: (185326035414)>
